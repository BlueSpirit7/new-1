# %% [markdown]
# <a href="https://colab.research.google.com/github/BlueSpirit7/new-1/blob/main/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***IMPORTATION OF FILE***

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-04b8f3d6-bcd5-4a86-b310-eb47d1747dc7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04b8f3d6-bcd5-4a86-b310-eb47d1747dc7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hamoye_project_1.csv to hamoye_project_1 (2).csv

# %%
import pandas as pd

# %%
df=pd.read_csv("hamoye_project_1.csv")

# %% [markdown]
# ***NUMBER OF ROWS AND COLUMNS***

# %%
df.shape
# Out:
# (44812, 95)

# %% [markdown]
# ***TOP FIVE ROWS***

# %%
df.head()
# Out:
#   Country Name Country Code  ... 2049 [YR2049]  2050 [YR2050]
# 0  Afghanistan          AFG  ...     44.471497      43.992485
# 1  Afghanistan          AFG  ...      7.935899       8.175734
# 2  Afghanistan          AFG  ...     36.535598      35.816751
# 3  Afghanistan          AFG  ...           NaN  430000.000000
# 4  Afghanistan          AFG  ...           NaN  452000.000000
#
# [5 rows x 95 columns]

# %% [markdown]
# ***IMPORTING LIBRARIES***

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %% [markdown]
# ***COLUMN TYPES***

# %%
df.dtypes
# Out:
# Country Name      object
# Country Code      object
# Series Name       object
# Series Code       object
# 1960 [YR1960]    float64
#                   ...
# 2046 [YR2046]    float64
# 2047 [YR2047]    float64
# 2048 [YR2048]    float64
# 2049 [YR2049]    float64
# 2050 [YR2050]    float64
# Length: 95, dtype: object

# %%
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print(numeric_cols)
# Out:
# ['1960 [YR1960]' '1961 [YR1961]' '1962 [YR1962]' '1963 [YR1963]'
#  '1964 [YR1964]' '1965 [YR1965]' '1966 [YR1966]' '1967 [YR1967]'
#  '1968 [YR1968]' '1969 [YR1969]' '1970 [YR1970]' '1971 [YR1971]'
#  '1972 [YR1972]' '1973 [YR1973]' '1974 [YR1974]' '1975 [YR1975]'
#  '1976 [YR1976]' '1977 [YR1977]' '1978 [YR1978]' '1979 [YR1979]'
#  '1980 [YR1980]' '1981 [YR1981]' '1982 [YR1982]' '1983 [YR1983]'
#  '1984 [YR1984]' '1985 [YR1985]' '1986 [YR1986]' '1987 [YR1987]'
#  '1988 [YR1988]' '1989 [YR1989]' '1990 [YR1990]' '1991 [YR1991]'
#  '1992 [YR1992]' '1993 [YR1993]' '1994 [YR1994]' '1995 [YR1995]'
#  '1996 [YR1996]' '1997 [YR1997]' '1998 [YR1998]' '1999 [YR1999]'
#  '2000 [YR2000]' '2001 [YR2001]' '2002 [YR2002]' '2003 [YR2003]'
#  '2004 [YR2004]' '2005 [YR2005]' '2006 [YR2006]' '2007 [YR2007]'
#  '2008 [YR2008]' '2009 [YR2009]' '2010 [YR2010]' '2011 [YR2011]'
#  '2012 [YR2012]' '2013 [YR2013]' '2014 [YR2014]' '2015 [YR2015]'
# ...

# %%
df_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print(non_numeric_cols)
# Out:
# ['Country Name' 'Country Code' 'Series Name' 'Series Code']

# %% [markdown]
# ***MISSING DATA HEAT MAP***

# %%
cols = df.columns[:30] # first 30 columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %% [markdown]
# ***MISSING DATA % LIST***

# %%
# if it's a larger dataset and the visualization takes too long can do this.
# % of missing.
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Country Name - 0%
# Country Code - 0%
# Series Name - 0%
# Series Code - 0%
# 1960 [YR1960] - 20%
# 1961 [YR1961] - 20%
# 1962 [YR1962] - 19%
# 1963 [YR1963] - 20%
# 1964 [YR1964] - 20%
# 1965 [YR1965] - 20%
# 1966 [YR1966] - 19%
# 1967 [YR1967] - 18%
# 1968 [YR1968] - 19%
# 1969 [YR1969] - 19%
# 1970 [YR1970] - 19%
# 1971 [YR1971] - 19%
# 1972 [YR1972] - 18%
# 1973 [YR1973] - 19%
# 1974 [YR1974] - 19%
# 1975 [YR1975] - 19%
# 1976 [YR1976] - 19%
# 1977 [YR1977] - 18%
# 1978 [YR1978] - 19%
# 1979 [YR1979] - 19%
# 1980 [YR1980] - 19%
# 1981 [YR1981] - 19%
# 1982 [YR1982] - 18%
# 1983 [YR1983] - 19%
# 1984 [YR1984] - 19%
# 1985 [YR1985] - 19%
# 1986 [YR1986] - 19%
# 1987 [YR1987] - 18%
# 1988 [YR1988] - 19%
# 1989 [YR1989] - 19%
# 1990 [YR1990] - 14%
# 1991 [YR1991] - 17%
# 1992 [YR1992] - 16%
# 1993 [YR1993] - 17%
# 1994 [YR1994] - 17%
# 1995 [YR1995] - 17%
# 1996 [YR1996] - 17%
# 1997 [YR1997] - 16%
# 1998 [YR1998] - 17%
# 1999 [YR1999] - 17%
# 2000 [YR2000] - 15%
# ...

# %% [markdown]
# ***MISSING DATA HISTOGRAM***

# %%
# first create missing indicator for features with missing data
for col in df.columns:
    missing = df[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  
        print('created missing indicator for: {}'.format(col))
        df['{}_ismissing'.format(col)] = missing


# then based on the indicator, plot the histogram of missing values
ismissing_cols = [col for col in df.columns if 'ismissing' in col]
df['num_missing'] = df[ismissing_cols].sum(axis=1)

df['num_missing'].value_counts().reset_index().sort_values(by='index').plot.bar(x='index', y='num_missing')
# Out:
# created missing indicator for: Country Name
# created missing indicator for: Country Code
# created missing indicator for: Series Name
# created missing indicator for: Series Code
# created missing indicator for: 1960 [YR1960]
# created missing indicator for: 1961 [YR1961]
# created missing indicator for: 1962 [YR1962]
# created missing indicator for: 1963 [YR1963]
# created missing indicator for: 1964 [YR1964]
# created missing indicator for: 1965 [YR1965]
# created missing indicator for: 1966 [YR1966]
# created missing indicator for: 1967 [YR1967]
# created missing indicator for: 1968 [YR1968]
# created missing indicator for: 1969 [YR1969]
# created missing indicator for: 1970 [YR1970]
# created missing indicator for: 1971 [YR1971]
# created missing indicator for: 1972 [YR1972]
# created missing indicator for: 1973 [YR1973]
# created missing indicator for: 1974 [YR1974]
# created missing indicator for: 1975 [YR1975]
# created missing indicator for: 1976 [YR1976]
# ...

# %% [markdown]
# ***REPLACING MISSING NUMERIC VALUES WITH MEDIAN***

# %%
# impute the missing values and create the missing value indicator variables for each numeric column.
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values

for col in numeric_cols:
    missing = df[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  # only do the imputation for the columns that have missing values.
        print('imputing missing values for: {}'.format(col))
        df['{}_ismissing'.format(col)] = missing
        med = df[col].median()
        df[col] = df[col].fillna(med)

# %%
df.shape
# Out:
# (44812, 186)

# %% [markdown]
# ***REPLACING NON NUMERIC COLUMNS WITH MODE***

# %%
# impute the missing values and create the missing value indicator variables for each non-numeric column.
df_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values

for col in non_numeric_cols:
    missing = df[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  # only do the imputation for the columns that have missing values.
        print('imputing missing values for: {}'.format(col))
        df['{}_ismissing'.format(col)] = missing
        
        top = df[col].describe()['top'] # impute with the most frequent value.
        df[col] = df[col].fillna(top)
# Out:
# imputing missing values for: Country Name
# imputing missing values for: Country Code
# imputing missing values for: Series Name
# imputing missing values for: Series Code

# %% [markdown]
# ***COLUMNS DOUBLED AFTER REPLACEMENT***

# %%
df.shape
# Out:
# (44812, 190)

# %%
df.isnull()
# Out:
#        Country Name  Country Code  ...  Series Name_ismissing  Series Code_ismissing
# 0             False         False  ...                  False                  False
# 1             False         False  ...                  False                  False
# 2             False         False  ...                  False                  False
# 3             False         False  ...                  False                  False
# 4             False         False  ...                  False                  False
# ...             ...           ...  ...                    ...                    ...
# 44807         False         False  ...                  False                  False
# 44808         False         False  ...                  False                  False
# 44809         False         False  ...                  False                  False
# 44810         False         False  ...                  False                  False
# ...

# %% [markdown]
# **OUTLIER BOX PLOT**

# %%
df.boxplot(column=['1960 [YR1960]'])

# %% [markdown]
# ***REMOVING DUPLICATES***

# %%
df. T. drop_duplicates(). T
# Out:
#                                             Country Name  ... Country Code_ismissing
# 0                                            Afghanistan  ...                  False
# 1                                            Afghanistan  ...                  False
# 2                                            Afghanistan  ...                  False
# 3                                            Afghanistan  ...                  False
# 4                                            Afghanistan  ...                  False
# ...                                                  ...  ...                    ...
# 44807                                        Afghanistan  ...                   True
# 44808                                        Afghanistan  ...                   True
# 44809                                        Afghanistan  ...                   True
# 44810  Data from database: Population estimates and p...  ...                   True
# ...

# %% [markdown]
# ***INCONSISTENT DATA CHECK***

# %%
df['1960 [YR1960]'].value_counts(dropna=False)
# Out:
# 4704.500000      8962
# 0.000000           13
# 100.000000          8
# 845.000000          7
# 868.000000          6
#                  ...
# 190850.000000       1
# 9.062811            1
# 2.903032            1
# 3.344212            1
# 4.879355            1
# Name: 1960 [YR1960], Length: 33568, dtype: int64

# %% [markdown]
# ***THE END***
