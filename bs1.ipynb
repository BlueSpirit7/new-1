# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-38979b70-38c9-4a4b-b2e8-d9f0b4de4967" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38979b70-38c9-4a4b-b2e8-d9f0b4de4967">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hamoye.csv to hamoye.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("hamoye.csv")

# %%
df.shape
# Out:
# (44812, 95)

# %%
df.head()
# Out:
#   Country Name Country Code  ... 2049 [YR2049]  2050 [YR2050]
# 0  Afghanistan          AFG  ...     44.471497      43.992485
# 1  Afghanistan          AFG  ...      7.935899       8.175734
# 2  Afghanistan          AFG  ...     36.535598      35.816751
# 3  Afghanistan          AFG  ...           NaN  430000.000000
# 4  Afghanistan          AFG  ...           NaN  452000.000000
#
# [5 rows x 95 columns]
