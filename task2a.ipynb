# %% [markdown]
# <a href="https://colab.research.google.com/github/BlueSpirit7/new-1/blob/main/task2a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***IMPORTATION OF FILE***

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-00df2bc1-be56-4cdf-925e-9f22d9f549a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00df2bc1-be56-4cdf-925e-9f22d9f549a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hamoye_project_1.csv to hamoye_project_1 (1).csv

# %%
import pandas as pd

# %%
df=pd.read_csv("hamoye_project_1 (1).csv")

# %% [markdown]
# ***NUMBER OF ROWS AND COLUMNS***

# %%
df.shape
# Out:
# (44812, 95)

# %% [markdown]
# ***TOP FIVE ROWS***

# %%
df.head()
# Out:
#   Country Name Country Code  ... 2049 [YR2049]  2050 [YR2050]
# 0  Afghanistan          AFG  ...     44.471497      43.992485
# 1  Afghanistan          AFG  ...      7.935899       8.175734
# 2  Afghanistan          AFG  ...     36.535598      35.816751
# 3  Afghanistan          AFG  ...           NaN  430000.000000
# 4  Afghanistan          AFG  ...           NaN  452000.000000
#
# [5 rows x 95 columns]

# %% [markdown]
# ***IMPORTING LIBRARIES***

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %% [markdown]
# ***COLUMN TYPES***

# %%
df.dtypes
# Out:
# Country Name      object
# Country Code      object
# Series Name       object
# Series Code       object
# 1960 [YR1960]    float64
#                   ...
# 2046 [YR2046]    float64
# 2047 [YR2047]    float64
# 2048 [YR2048]    float64
# 2049 [YR2049]    float64
# 2050 [YR2050]    float64
# Length: 95, dtype: object

# %%
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print(numeric_cols)
# Out:
# ['1960 [YR1960]' '1961 [YR1961]' '1962 [YR1962]' '1963 [YR1963]'
#  '1964 [YR1964]' '1965 [YR1965]' '1966 [YR1966]' '1967 [YR1967]'
#  '1968 [YR1968]' '1969 [YR1969]' '1970 [YR1970]' '1971 [YR1971]'
#  '1972 [YR1972]' '1973 [YR1973]' '1974 [YR1974]' '1975 [YR1975]'
#  '1976 [YR1976]' '1977 [YR1977]' '1978 [YR1978]' '1979 [YR1979]'
#  '1980 [YR1980]' '1981 [YR1981]' '1982 [YR1982]' '1983 [YR1983]'
#  '1984 [YR1984]' '1985 [YR1985]' '1986 [YR1986]' '1987 [YR1987]'
#  '1988 [YR1988]' '1989 [YR1989]' '1990 [YR1990]' '1991 [YR1991]'
#  '1992 [YR1992]' '1993 [YR1993]' '1994 [YR1994]' '1995 [YR1995]'
#  '1996 [YR1996]' '1997 [YR1997]' '1998 [YR1998]' '1999 [YR1999]'
#  '2000 [YR2000]' '2001 [YR2001]' '2002 [YR2002]' '2003 [YR2003]'
#  '2004 [YR2004]' '2005 [YR2005]' '2006 [YR2006]' '2007 [YR2007]'
#  '2008 [YR2008]' '2009 [YR2009]' '2010 [YR2010]' '2011 [YR2011]'
#  '2012 [YR2012]' '2013 [YR2013]' '2014 [YR2014]' '2015 [YR2015]'
# ...

# %%
df_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print(non_numeric_cols)
# Out:
# ['Country Name' 'Country Code' 'Series Name' 'Series Code']

# %% [markdown]
# ***MISSING DATA HEAT MAP***

# %%
cols = df.columns 
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %% [markdown]
# ***MISSING DATA % LIST***

# %%
df.isnull().sum()
# Out:
# Country Name         3
# Country Code         5
# Series Name          5
# Series Code          5
# 1960 [YR1960]     8962
#                  ...
# 2046 [YR2046]    21753
# 2047 [YR2047]    20880
# 2048 [YR2048]    21753
# 2049 [YR2049]    21753
# 2050 [YR2050]    10307
# Length: 95, dtype: int64

# %%
# if it's a larger dataset and the visualization takes too long can do this.
# % of missing.
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100,4)))
# Out:
# Country Name - 0.0067%
# Country Code - 0.0112%
# Series Name - 0.0112%
# Series Code - 0.0112%
# 1960 [YR1960] - 19.9991%
# 1961 [YR1961] - 19.6956%
# 1962 [YR1962] - 18.6401%
# 1963 [YR1963] - 19.6086%
# 1964 [YR1964] - 19.5394%
# 1965 [YR1965] - 19.5015%
# 1966 [YR1966] - 19.4747%
# 1967 [YR1967] - 18.4036%
# 1968 [YR1968] - 19.3899%
# 1969 [YR1969] - 19.2962%
# 1970 [YR1970] - 19.2181%
# 1971 [YR1971] - 19.1935%
# 1972 [YR1972] - 18.1224%
# 1973 [YR1973] - 19.1578%
# 1974 [YR1974] - 19.1377%
# 1975 [YR1975] - 19.0909%
# 1976 [YR1976] - 19.0574%
# 1977 [YR1977] - 18.0086%
# 1978 [YR1978] - 18.9994%
# 1979 [YR1979] - 18.9659%
# 1980 [YR1980] - 18.928%
# 1981 [YR1981] - 18.8789%
# 1982 [YR1982] - 17.7832%
# 1983 [YR1983] - 18.8142%
# 1984 [YR1984] - 18.7561%
# 1985 [YR1985] - 18.7494%
# 1986 [YR1986] - 18.7182%
# 1987 [YR1987] - 17.6337%
# 1988 [YR1988] - 18.7137%
# 1989 [YR1989] - 18.7003%
# 1990 [YR1990] - 14.3622%
# 1991 [YR1991] - 16.9687%
# 1992 [YR1992] - 16.0203%
# ...

# %%
df.shape
# Out:
# (44812, 95)

# %% [markdown]
# ***REPLACING MISSING NUMERIC VALUES WITH MEDIAN***

# %%
for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
df.shape
# Out:
# (44812, 95)

# %%
df[numeric_cols].isnull().sum()
# Out:
# 1960 [YR1960]    0
# 1961 [YR1961]    0
# 1962 [YR1962]    0
# 1963 [YR1963]    0
# 1964 [YR1964]    0
#                 ..
# 2046 [YR2046]    0
# 2047 [YR2047]    0
# 2048 [YR2048]    0
# 2049 [YR2049]    0
# 2050 [YR2050]    0
# Length: 91, dtype: int64

# %% [markdown]
# ***REPLACING NON NUMERIC DATA***

# %%
for col in non_numeric_cols:
    df[col] = df[col].fillna(df[col].describe()['top'])

# %%
df.isnull().sum()
# Out:
# Country Name     0
# Country Code     0
# Series Name      0
# Series Code      0
# 1960 [YR1960]    0
#                 ..
# 2046 [YR2046]    0
# 2047 [YR2047]    0
# 2048 [YR2048]    0
# 2049 [YR2049]    0
# 2050 [YR2050]    0
# Length: 95, dtype: int64

# %%
df.shape
# Out:
# (44812, 95)

# %%
df.isnull()
# Out:
#        Country Name  Country Code  ...  2049 [YR2049]  2050 [YR2050]
# 0             False         False  ...          False          False
# 1             False         False  ...          False          False
# 2             False         False  ...          False          False
# 3             False         False  ...          False          False
# 4             False         False  ...          False          False
# ...             ...           ...  ...            ...            ...
# 44807         False         False  ...          False          False
# 44808         False         False  ...          False          False
# 44809         False         False  ...          False          False
# 44810         False         False  ...          False          False
# 44811         False         False  ...          False          False
#
# [44812 rows x 95 columns]

# %%
df.head()
# Out:
#   Country Name Country Code  ... 2049 [YR2049]  2050 [YR2050]
# 0  Afghanistan          AFG  ...     44.471497      43.992485
# 1  Afghanistan          AFG  ...      7.935899       8.175734
# 2  Afghanistan          AFG  ...     36.535598      35.816751
# 3  Afghanistan          AFG  ...     67.239426  430000.000000
# 4  Afghanistan          AFG  ...     67.239426  452000.000000
#
# [5 rows x 95 columns]

# %%
df.tail()
# Out:
#                                             Country Name  ... 2050 [YR2050]
# 44807                                        Afghanistan  ...       21000.0
# 44808                                        Afghanistan  ...       21000.0
# 44809                                        Afghanistan  ...       21000.0
# 44810  Data from database: Population estimates and p...  ...       21000.0
# 44811                           Last Updated: 07/03/2017  ...       21000.0
#
# [5 rows x 95 columns]

# %% [markdown]
# ***THE END***
